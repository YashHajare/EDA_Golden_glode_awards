# %% [markdown]
# <a href="https://colab.research.google.com/github/YashHajare/EDA_Golden_glode_awards/blob/main/Golden_Glode_Awards_EDA_(Final).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<h1>Golden Glode Awards EDA</h1>**

# %% [markdown]
# <a href="https://drive.google.com/file/d/1JG7wq59cyTgYGfHfx9RwJF0UXOautxR7/view?usp=sharing"> Movie Dataset </a>
#
# Link: https://drive.google.com/file/d/1JG7wq59cyTgYGfHfx9RwJF0UXOautxR7/view?usp=sharing

# %% [markdown]
# <h2>1. Importing data and getting basic information</h2>

# %%
import pandas as pd

data = pd.read_csv("/content/golden_globe_awards.csv")

print("Printing Head side :\n")
data.head()
# Out:
# Printing Head side :
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                       film   win
# 0  For Whom The Bell Tolls  True
# 1  For Whom The Bell Tolls  True
# 2   The Song Of Bernadette  True
# 3                      NaN  True
# 4   The Song Of Bernadette  True

# %% [markdown]
# <h2> About Dataset: </h2>
# <h2> The Golden Globe Awards are accolades bestowed by the 105 members of the Hollywood Foreign Press Association beginning in January 1944, recognizing excellence in both American and international film and television. </h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Printing Tail side :\n")
data.tail()
# Out:
# Printing Tail side :
#       year_film  year_award  ceremony  \
# 7986       2019        2020        77
# 7987       2019        2020        77
# 7988       2019        2020        77
# 7989       2019        2020        77
# 7990       2019        2020        77
#
#                                                category          nominee  \
# 7986  Best Performance by an Actor in a Supporting R...    Kieran Culkin
# 7987  Best Performance by an Actor in a Supporting R...     Andrew Scott
# 7988  Best Performance by an Actor in a Supporting R...    Henry Winkler
# 7989                             Cecil B. deMille Award        Tom Hanks
# 7990                                Carol Burnett Award  Ellen DeGeneres
#
#             film    win
# 7986  Succession  False
# 7987     Fleabag  False
# 7988       Barry  False
# 7989         NaN  False
# 7990         NaN  False

# %% [markdown]
# <h2> 1.1 Printing demension of data

# %%
data.shape
# Out:
# (7991, 7)

# %% [markdown]
# <h2> 1.2 Printing Column name </h2>

# %%
data.columns
# Out:
# Index(['year_film', 'year_award', 'ceremony', 'category', 'nominee', 'film',
#        'win'],
#       dtype='object')

# %% [markdown]
# <h2> 1.3 Description of data </h2>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year_film   7991 non-null   int64
#  1   year_award  7991 non-null   int64
#  2   ceremony    7991 non-null   int64
#  3   category    7991 non-null   object
#  4   nominee     7991 non-null   object
#  5   film        6191 non-null   object
#  6   win         7991 non-null   bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 382.5+ KB

# %% [markdown]
# <p> Here, 'film' column has 6191 entries compared to other</p>

# %%
data.describe()
# Out:
#          year_film   year_award     ceremony
# count  7991.000000  7991.000000  7991.000000
# mean   1987.490552  1988.490552    45.490552
# std      18.936258    18.936258    18.936258
# min    1943.000000  1944.000000     1.000000
# 25%    1972.000000  1973.000000    30.000000
# 50%    1988.000000  1989.000000    46.000000
# 75%    2004.000000  2005.000000    62.000000
# max    2019.000000  2020.000000    77.000000

# %% [markdown]
# <h2> 1.4 Finding NULL and NaN values </h2>

# %%
data.isnull().any()
# Out:
# year_film     False
# year_award    False
# ceremony      False
# category      False
# nominee       False
# film           True
# win           False
# dtype: bool

# %% [markdown]
# <h2> Here, we have found there are NaN values in 'film' column. </h2>

# %%
data.isnull().sum()
# Out:
# year_film        0
# year_award       0
# ceremony         0
# category         0
# nominee          0
# film          1800
# win              0
# dtype: int64

# %% [markdown]
# <h2> In the above code, we found that there are 1800 NaN values in 'film' column.</h2>
# <h2> and shape of dataset is 7991, 7</h2>

# %%
data = data.fillna("Other")

# %%
data.isnull().sum()
# Out:
# year_film     0
# year_award    0
# ceremony      0
# category      0
# nominee       0
# film          0
# win           0
# dtype: int64

# %% [markdown]
# <h2> NaN values are converted</h2>

# %%
data.tail()
# Out:
#       year_film  year_award  ceremony  \
# 7986       2019        2020        77
# 7987       2019        2020        77
# 7988       2019        2020        77
# 7989       2019        2020        77
# 7990       2019        2020        77
#
#                                                category          nominee  \
# 7986  Best Performance by an Actor in a Supporting R...    Kieran Culkin
# 7987  Best Performance by an Actor in a Supporting R...     Andrew Scott
# 7988  Best Performance by an Actor in a Supporting R...    Henry Winkler
# 7989                             Cecil B. deMille Award        Tom Hanks
# 7990                                Carol Burnett Award  Ellen DeGeneres
#
#             film    win
# 7986  Succession  False
# 7987     Fleabag  False
# 7988       Barry  False
# 7989       Other  False
# 7990       Other  False

# %%
temp = data[data["film"] == "Other"].tail(10)
temp
# Out:
#       year_film  year_award  ceremony  \
# 7941       2019        2020        77
# 7942       2019        2020        77
# 7943       2019        2020        77
# 7944       2019        2020        77
# 7945       2019        2020        77
# 7946       2019        2020        77
# 7947       2019        2020        77
# 7948       2019        2020        77
# 7989       2019        2020        77
# 7990       2019        2020        77
#
#                                                category  \
# 7941         Best Television Series - Musical or Comedy
# 7942         Best Television Series - Musical or Comedy
# 7943         Best Television Series - Musical or Comedy
# 7944  Best Television Limited Series or Motion Pictu...
# 7945  Best Television Limited Series or Motion Pictu...
# 7946  Best Television Limited Series or Motion Pictu...
# 7947  Best Television Limited Series or Motion Pictu...
# 7948  Best Television Limited Series or Motion Pictu...
# ...

# %%
data.nunique()
# Out:
# year_film       77
# year_award      77
# ceremony        77
# category        76
# nominee       4292
# film          3084
# win              2
# dtype: int64

# %%
# data['win'] == True

len(data.loc[:,'win'] == True)
# Out:
# 7991

# %%
data["win"].value_counts()
# Out:
# False    6166
# True     1825
# Name: win, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
sns.countplot(data["win"])

# temp = data.copy()
# temp["win_int"] = temp.win.replace({True: 1, False: 0})
# temp.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <h2> "False" value are far greater than "True" </h2>

# %% [markdown]
# <h2> 2.0 Category of Awards</h2>

# %%
len(data.category.unique())
# Out:
# 76

# %% [markdown]
# <h2> It was found that, there are <i>76 different </i> types of awards given at 'Golden Glode Award'</h2>

# %%
data.category.unique()
# Out:
# array(['Best Performance by an Actress in a Supporting Role in any Motion Picture',
#        'Best Performance by an Actor in a Supporting Role in any Motion Picture',
#        'Best Director - Motion Picture', 'Picture',
#        'Actress In A Leading Role', 'Actor In A Leading Role',
#        'Promoting International Understanding',
#        'Special Achievement Award', 'Best Screenplay - Motion Picture',
#        'Best Original Score - Motion Picture',
#        'New Star Of The Year - Actress', 'New Star Of The Year - Actor',
#        'Juvenile Performance', 'Cinematography',
#        'Foreign Film - English Language',
#        'Best Motion Picture - Foreign Language',
#        'Outstanding Use Of Color',
#        'Best Performance by an Actress in a Motion Picture - Drama',
#        'Best Performance by an Actor in a Motion Picture - Drama',
#        'Best Performance by an Actor in a Motion Picture - Musical or Comedy',
#        'New Star Of The Year',
# ...

# %% [markdown]
# <h2> 2.1 Nominee exploration</h2>

# %%
len(data.nominee.unique())
# Out:
# 4292

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

top_nominee = data.nominee.tolist()

print(len(top_nominee))

unique_string=(" ").join(top_nominee)
wordcloud = WordCloud().generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.show()
# Out:
# 7991

# %%
data.loc[data['win'] == True]
# Out:
#       year_film  year_award  ceremony  \
# 0          1943        1944         1
# 1          1943        1944         1
# 2          1943        1944         1
# 3          1943        1944         1
# 4          1943        1944         1
# ...         ...         ...       ...
# 7964       2019        2020        77
# 7969       2019        2020        77
# 7974       2019        2020        77
# 7979       2019        2020        77
# 7984       2019        2020        77
#
#                                                category  \
# 0     Best Performance by an Actress in a Supporting...
# 1     Best Performance by an Actor in a Supporting R...
# 2                        Best Director - Motion Picture
# 3                                               Picture
# 4                             Actress In A Leading Role
# ...                                                 ...
# 7964  Best Performance by an Actor In A Television S...
# ...

# %% [markdown]
# <h2> 2.2 Top Films nominated </h2>

# %%
temp = data[data["film"] != "Other"]

top_films = temp.film.value_counts()

top_films.head(8)
# Out:
# L.A. Law                   26
# Will & Grace               23
# All In The Family          23
# Cheers                     22
# Taxi                       20
# Carol Burnett Show, The    19
# Dynasty (1981-1989)        19
# Sex and The City           18
# Name: film, dtype: int64

# %%
top_nominee = temp.nominee.value_counts()

top_nominee.head(20)
# Out:
# Meryl Streep          32
# John Williams         23
# Jack Lemmon           22
# Shirley MacLaine      19
# Al Pacino             18
# Jack Nicholson        17
# Helen Mirren          16
# Alan Alda             16
# Carol Burnett         16
# Jessica Lange         15
# Angela Lansbury       15
# Nicole Kidman         14
# Woody Allen           13
# Dustin Hoffman        13
# Steven Spielberg      13
# Candice Bergen        13
# Glenn Close           13
# Vanessa Redgrave      13
# Julianna Margulies    12
# Maggie Smith          12
# Name: nominee, dtype: int64

# %% [markdown]
# <h2> 3.0 Top 8 films that won maximum awards in a year</h2>

# %%
golden_globe = data

# %%
golden_year_max=golden_globe.groupby(["year_award","film"])['win'].sum().head(8)
golden_year_max.to_frame()
# Out:
#                                     win
# year_award film
# 1944       For Whom The Bell Tolls    2
#            Other                      1
#            The Song Of Bernadette     2
#            Watch On The Rhine         1
# 1945       Gaslight                   1
#            Going My Way               2
#            Mrs. Parkington            1
#            Other                      1

# %% [markdown]
# Among the 8 films,"From whom the bell tolls" and "The song of bernadette" are the most awarded films in the year 1944

# %% [markdown]
# By country

# %%
import re
pattern = re.compile('[A-z ]+,')

def get_country(film):
    rs = re.findall(pattern, film)
    if(rs):
        return (rs[0]).replace(',','')
    else:
        return ''

# %%
golden_globe['country']=golden_globe[golden_globe['category'].str.contains('Best Motion Picture - Foreign Language')]['film'].apply(get_country)

# %% [markdown]
# The nominee for which country received  maximum award?

# %%
golden_globecountry_max=golden_globe.groupby(["country","year_award"])['win'].sum()
golden_nomiee_country=golden_globe.groupby(["category","nominee"]).nunique()
golden_nomiee_country=golden_globe.groupby(["country","nominee"]).nunique()
golden_nomiee_country.sort_values(by="win")
# Out:
#                                              year_film  year_award  ceremony  \
# country    nominee
#            Dangerous Curves (UK)                     1           1         1
# Italy      The Bicycle Thief                         1           1         1
#            The Great Beauty                          1           1         1
#            Till Marriage Do Us Part                  1           1         1
#            Traviata, La                              1           1         1
# ...                                                ...         ...       ...
# France     Persepolis                                1           1         1
#            Portrait of a Lady on Fire                1           1         1
#            Jean De Florette                          1           1         1
# Yugoslavia When Father Was Away on Business          1           1         1
# France     Les Misérables                            2           2         2
#
# ...

# %% [markdown]
# Ingmar Bergaman ,Ismael Rodrigues,Ephraim Kishon,Pietro Germi,Kon Ichikawa and Federico Fellini for countries Sweden,Mexico,Israel,Italy, Japan and Italy received more awards

# %% [markdown]
# <h2> In which Ceremony,the country received two awards?
#  </h2>

# %%
golden_ceremony=golden_globe.groupby(["ceremony","country"])["win"].value_counts().head(20)
golden_ceremony
# Out:
# ceremony  country         win
# 7         Italy           True     1
#           United Kingdom  False    1
# 12        Argentina       True     1
#           Japan           True     1
#           United Kingdom  True     1
#           West Germany    True     1
# 13                        True     1
#           Denmark         True     1
#           Greece          True     1
#           Japan           True     1
#           West Germany    True     1
# 31        France          False    2
#           Israel          False    1
#           Italy           False    1
#           West Germany    True     1
# 32        Canada          False    1
#           France          False    2
#           Italy           False    1
#           Sweden          True     1
# 33        Canada          True     1
# Name: win, dtype: int64

# %% [markdown]
# In ceremony 17,West Germany received two awards

# %% [markdown]
# Distribution of nomination by the countries

# %%
top_country = golden_globe.country.value_counts()

top_country.plot.pie(autopct='%.0f%%',figsize=(10, 10))

print(top_country)
# Out:
# France                               56
# Italy                                22
# Germany                              15
# Spain                                12
# United Kingdom                       11
# Sweden                                9
# Canada                                8
# Japan                                 7
# Russia                                7
# Denmark                               7
# China                                 6
# West Germany                          6
# Mexico                                6
# Brazil                                6
# Belgium                               6
# United States                         5
# Taiwan                                4
# Australia                             4
# Israel                                4
# Chile                                 4
# India                                 3
# Switzerland                           3
# Hungary                               3
# ...

# %% [markdown]
# From the pie chart,we can say that France contributed 24% of the nomination and Italy,22% of the nomination

# %% [markdown]
# <h2> 3.4 List of 20 films by the countries that won 1 award</h2>

# %%
golden_globe_country_film=golden_globe.groupby(["country","film"])["win"].sum().sort_values().tail(20)
golden_globe_country_film
# Out:
# country         film
# Italy           Italy, Ettore Scola             1
#                 Italy, Giuseppe Tornatore       1
#                 United Kingdom                  1
# Italy           Italy, Paolo Sorrentino         1
# Canada          Canada, Ján Kadár               1
# Spain           Spain, Alejandro Amenábar       1
# South Korea     South Korea, Bong Joon Ho       1
# Russia          Russia, Andrey Zvyagintsev      1
# Palestine       Palestine, Hany Abu-Assad       1
# Sweden          Sweden, Lasse Hallström         1
# Czech Republic  Czech Republic, Jan Sverák      1
# Denmark         Denmark, Carl Theodor Dreyer    1
# Netherlands     Netherlands, Fons Rademakers    1
# Denmark         Denmark, Susanne Bier           1
# Japan           Japan, Yoshirô Kawazu           1
#                 Japan, Keisuke Kinoshita        1
# Italy           Italy, Vittorio De Sica         1
# Denmark         Denmark, Bille August           1
# ...

# %% [markdown]
# <h2> 4.0 Most Nominated Person</h2>

# %%
data['nominee'].value_counts().nlargest(20)
# Out:
# Meryl Streep        33
# Jack Lemmon         23
# John Williams       23
# Shirley MacLaine    21
# Al Pacino           19
# Jack Nicholson      18
# Carol Burnett       17
# Paul Newman         16
# Barbra Streisand    16
# Alan Alda           16
# Jessica Lange       16
# Helen Mirren        16
# Jane Fonda          15
# Angela Lansbury     15
# Steven Spielberg    14
# Nicole Kidman       14
# Woody Allen         14
# Dustin Hoffman      14
# Candice Bergen      13
# Vanessa Redgrave    13
# Name: nominee, dtype: int64

# %%
data.loc[data['win'] == True]['nominee'].value_counts()
# Out:
# Meryl Streep                      8
# Jane Fonda                        7
# Barbra Streisand                  7
# Angela Lansbury                   6
# Paul Newman                       6
#                                  ..
# Elvis on Tour                     1
# That Certain Summer               1
# Life of Leonardo Da Vinci, The    1
# Edward Albert                     1
# Stellan Skarsgård                 1
# Name: nominee, Length: 1372, dtype: int64

# %% [markdown]
# From the above output, we could see that even though the top 3 nomimees are Meryl,Jack and John who are nominated 33 to 23 times.
# They haven't actually won that many times.
# which makes their winning ratio very little.

# %% [markdown]
# On the other hand if we take Jane for an example who has been nominated less than half the time that Meryl was nominated but yet she has won about the same number of times. Which makes her winning ratio better.

# %%
import seaborn as sb
import matplotlib.pyplot as plt 

plt.figure(figsize=(15,10))
d = data['nominee'].value_counts().nlargest(20)
df = data[data['nominee'].isin(d.index)]
sb.countplot(x='nominee', hue='win', data=df,order=d.index)
plt.xticks(rotation=90, fontsize=16)
plt.xlabel("Nominee", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.yticks(fontsize=16)
plt.title("Most Nominated Person")
# Out:
# Text(0.5, 1.0, 'Most Nominated Person')

# %%
#Nominee who received the most awards overall year?
data.loc[data['win'] == True]['nominee'].value_counts()
# Out:
# Meryl Streep                      8
# Jane Fonda                        7
# Barbra Streisand                  7
# Angela Lansbury                   6
# Paul Newman                       6
#                                  ..
# Elvis on Tour                     1
# That Certain Summer               1
# Life of Leonardo Da Vinci, The    1
# Edward Albert                     1
# Stellan Skarsgård                 1
# Name: nominee, Length: 1372, dtype: int64

# %% [markdown]
# <h2> 4.1 Most Nominated Film </h2>

# %%
data.loc[data['win'] == True]['film'].value_counts().nlargest(10)
# Out:
# Other                              425
# Alice                                7
# Carol Burnett Show, The              7
# M*A*S*H (TV Show)                    7
# La La Land                           6
# 30 Rock                              5
# Lawrence Of Arabia                   5
# One Flew Over The Cuckoo's Nest      5
# Sex and The City                     5
# Cheers                               5
# Name: film, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
temp = data[data["film"] != "Other"]

df = temp['film'].value_counts().nlargest(20)
df = temp[temp['film'].isin(df.index)]
sb.countplot(x='film', hue='win', data=df)
plt.xticks(rotation=90, fontsize=16)
plt.xlabel("Film", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.yticks(fontsize=16)
plt.title("Most Nominated Film")
# Out:
# Text(0.5, 1.0, 'Most Nominated Film')

# %% [markdown]
# <h2>4.2 Awards in Each Year

# %%
#In which year most awards awards were received?
data.loc[data['win'] == True]['year_award'].value_counts()
# Out:
# 1963    32
# 1989    32
# 1957    32
# 1959    31
# 1973    31
#         ..
# 1948    12
# 1947     7
# 1946     7
# 1945     6
# 1944     6
# Name: year_award, Length: 77, dtype: int64

# %%
#count plot for the year winning most awards to least
plt.figure(figsize=(15,50))
sb.countplot(y=data.loc[data['win'] == True]['year_award'],data=data,order = data.loc[data['win'] == True]['year_award'].value_counts().index)

# %% [markdown]
# <h2>4.3 Most in Categories

# %%
#nominated
data['category'].value_counts()
# Out:
# Best Performance by an Actress in a Supporting Role in any Motion Picture    360
# Best Director - Motion Picture                                               357
# Best Performance by an Actor in a Supporting Role in any Motion Picture      352
# Best Motion Picture - Drama                                                  351
# Best Performance by an Actor in a Motion Picture - Drama                     344
#                                                                             ...
# International News Coverage                                                    1
# Television Producer/Director                                                   1
# New Foreign Star Of The Year - Actor                                           1
# New Foreign Star Of The Year - Actress                                         1
# Famous Silent Filmstars                                                        1
# Name: category, Length: 76, dtype: int64

# %%
#Top 10 categories that won
data.loc[data['win'] == True]['category'].value_counts().nlargest(10)
# Out:
# Best Performance by an Actress in a Supporting Role in any Motion Picture    79
# Best Director - Motion Picture                                               77
# Best Performance by an Actor in a Supporting Role in any Motion Picture      77
# Best Performance by an Actress in a Motion Picture - Drama                   71
# Best Performance by an Actor in a Motion Picture - Drama                     71
# Best Performance by an Actor in a Motion Picture - Musical or Comedy         70
# Best Motion Picture - Drama                                                  69
# Best Original Score - Motion Picture                                         66
# Best Motion Picture - Musical or Comedy                                      63
# Best Screenplay - Motion Picture                                             63
# Name: category, dtype: int64

# %% [markdown]
# <h2> 5.0 Analysis with year</h2>

# %%
data = df

# %%
# We can also use the first function from pandas to be able to see when the awards were first introducted

first_film_award = df[['category','year_award']].groupby('category').first().reset_index()

# Add in true within the column

first_film_award.rename({"year_award": "award_first_awarded"}, axis=1, inplace=True)

#here is a overview of the first awards 
first_film_award.head(10)
# Out:
#                                             category  award_first_awarded
# 0  Actor In A Leading Role - Musical Or Comedy Se...                 1972
# 1  Actor In A Supporting Role - Series Or Televis...                 1972
# 2  Actress In A Leading Role - Musical Or Comedy ...                 1972
# 3  Actress In A Supporting Role - Series Or Telev...                 1972
# 4                     Actress In A Television Series                 1968
# 5  Actress In A Television Series - Musical Or Co...                 1970
# 6  Best Performance by an Actor In A Television S...                 1974
# 7  Best Performance by an Actor in a Supporting R...                 1973
# 8  Best Performance by an Actor in a Television S...                 1973
# 9  Best Performance by an Actress In A Television...                 1973

# %%
df["decade_film_award"] = df.year_award.astype(str)
df["decade_film_award"] = df['decade_film_award'].str[:3]+'0s'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import seaborn as sns

plt.figure(figsize=(15,6))
sns.countplot(data=df, x='decade_film_award',   palette='hls')
plt.title('Counts of Nominations for the Golden Globe awards from 1944-2020', fontsize=15)
plt.xlabel('Decade')
plt.ylabel("Count")
plt.legend(frameon=False, fontsize=12)
# Out:
# No handles with labels found to put in legend.

# %%
# Total Nominees in each decade
df_nominees = df.groupby('decade_film_award')['win'].count().to_frame('Count').reset_index()
print(df_nominees)
# Out:
#   decade_film_award  Count
# 0             1960s      1
# 1             1970s     86
# 2             1980s    104
# 3             1990s     64
# 4             2000s     81
# 5             2010s     10

# %%
# Total Winners in each decade
df_winners=df[df.win == True]
df_winners_decade = df_winners.groupby('decade_film_award')['win'].count().to_frame('Count').reset_index()
print(df_winners_decade)

df_winners_decade.dtypes
# Out:
#   decade_film_award  Count
# 0             1960s      1
# 1             1970s     19
# 2             1980s     22
# 3             1990s      8
# 4             2000s     16
# 5             2010s      1
# decade_film_award    object
# Count                 int64
# dtype: object
